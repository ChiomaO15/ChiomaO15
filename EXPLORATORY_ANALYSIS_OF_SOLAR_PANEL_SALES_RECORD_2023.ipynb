# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiomaO15/ChiomaO15/blob/main/EXPLORATORY_ANALYSIS_OF_SOLAR_PANEL_SALES_RECORD_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **LOADING DATA AND DATA DESCRIPTION**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/SOLAR PANEL SALES 2023.csv')
df
# Out:
#            DATE  WATT  QTY      RATE
# 0    04/01/2023   600   30  167000.0
# 1    04/01/2023   600   30  170000.0
# 2    05/01/2023   600   10  168000.0
# 3    08/01/2023   600   15  168000.0
# 4    09/01/2023   600   34  167000.0
# ..          ...   ...  ...       ...
# 185  18/12/2023   455  100  138000.0
# 186  19/12/2023   600  126  178000.0
# 187  21/12/2023   380   12  114000.0
# 188  12/24/2023   380    6  114000.0
# 189  12/27/2023   600    6  180000.0
#
# [190 rows x 4 columns]

# %%
df.head()
# Out:
#          DATE  WATT  QTY      RATE
# 0  04/01/2023   600   30  167000.0
# 1  04/01/2023   600   30  170000.0
# 2  05/01/2023   600   10  168000.0
# 3  08/01/2023   600   15  168000.0
# 4  09/01/2023   600   34  167000.0

# %%
df.tail()
# Out:
#            DATE  WATT  QTY      RATE
# 185  18/12/2023   455  100  138000.0
# 186  19/12/2023   600  126  178000.0
# 187  21/12/2023   380   12  114000.0
# 188  12/24/2023   380    6  114000.0
# 189  12/27/2023   600    6  180000.0

# %%
df.shape
# Out:
# (190, 4)

# %%
df.dtypes
# Out:
# DATE     object
# WATT      int64
# QTY       int64
# RATE    float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of            DATE  WATT  QTY      RATE
# 0    04/01/2023   600   30  167000.0
# 1    04/01/2023   600   30  170000.0
# 2    05/01/2023   600   10  168000.0
# 3    08/01/2023   600   15  168000.0
# 4    09/01/2023   600   34  167000.0
# ..          ...   ...  ...       ...
# 185  18/12/2023   455  100  138000.0
# 186  19/12/2023   600  126  178000.0
# 187  21/12/2023   380   12  114000.0
# 188  12/24/2023   380    6  114000.0
# 189  12/27/2023   600    6  180000.0
#
# [190 rows x 4 columns]>

# %%
df.columns
# Out:
# Index(['DATE', 'WATT', 'QTY', 'RATE'], dtype='object')

# %% [markdown]
# ## **DATA CLEANING**

# %%
df.dropna(inplace = True)

print(df.to_string())
# Out:
#            DATE  WATT  QTY       RATE
# 0    04/01/2023   600   30  167000.00
# 1    04/01/2023   600   30  170000.00
# 2    05/01/2023   600   10  168000.00
# 3    08/01/2023   600   15  168000.00
# 4    09/01/2023   600   34  167000.00
# 5    09/01/2023   600   10  168000.00
# 6    10/01/2023   600   25  168000.00
# 7    10/01/2023   450   15  130000.00
# 8    13/01/2023   380   50  107000.00
# 9    13/01/2023   380   60  109000.00
# 10   16/01/2023   380    1  108000.00
# 11   25/01/2023   380    1  108000.00
# 12   29/01/2023   380   16  106400.00
# 13   01/02/2023   600    3  172000.00
# 14   05/02/2023   600    8  168000.00
# 15   12/02/2023   600   30  168000.00
# 16   16/02/2023   380   20  105000.00
# 17   17/02/2023   380   60  107000.00
# 18   19/02/2023   380    4  107000.00
# 19   20/02/2023   380    6  107000.00
# 20   21/02/2023   380    9  107000.00
# 21   22/02/2023   380   70  105000.00
# 22   22/02/2023   380   14  107000.00
# 23   25/02/2023   380   20  106400.00
# ...

# %%
df.isnull().sum()
# Out:
# DATE    0
# WATT    0
# QTY     0
# RATE    0
# dtype: int64

# %%
df.describe()
# Out:
#              WATT         QTY           RATE
# count  190.000000  190.000000     190.000000
# mean   506.157895   18.815789  145262.461947
# std     94.990817   27.109669   26921.661249
# min    375.000000    1.000000  102500.000000
# 25%    405.000000    6.000000  121500.000000
# 50%    545.000000   10.000000  155583.500000
# 75%    600.000000   20.000000  168000.000000
# max    665.000000  246.000000  202000.000000

# %% [markdown]
# ## **UNIVARIATE ANALYSIS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
# Assuming 'df' is your DataFrame
WATT_counts = df['WATT'].value_counts()

# Using Matplotlib to create a count plot
plt.figure(figsize=(8, 6))
plt.bar(WATT_counts.index, WATT_counts, color='green')
plt.title('Count WATT QUALITY')
plt.xlabel('WATT')
plt.ylabel('Count')
plt.show()

# %% [markdown]
#  From the plot above,we notice that 600W was sold more than any other Watt.

# %% [markdown]
# ## **USING SWARM PLOT TO UNDERSTAND THE RELATIONSHIP BETWEEN THE QUANTITY AND WATT**

# %%
# Assuming 'df' is your DataFrame
plt.figure(figsize=(10, 8))

# Using Seaborn to create a swarm plot
sns.swarmplot(x="WATT", y="QTY", data=df, palette='viridis')

plt.title('Swarm Plot for WATT and QTY')
plt.xlabel('WATT')
plt.ylabel('QTY')
plt.show()

# %% [markdown]
# According to the swarm plot, even though 600 WATT was sold more, 455Watt had the highest quantity sold.

# %% [markdown]
# ## **USING BOXPLOT TO VISUALIZE DATA**

# %%
# Check the column names of the DataFrame
print(df.columns)

# Load the data again with the correct column names
df = pd.read_csv("/content/SOLAR PANEL SALES 2023.csv", names=["DATE", "WATT", "QTY", "RATE"])
# Out:
# Index(['WATT', 'QTY'], dtype='object')

# %%
# Create boxplots for WATT and QTY
fig, axs = plt.subplots(2, 2, figsize=(15, 8))
sns.boxplot(df['WATT'], ax=axs[0, 0])
sns.boxplot(df['QTY'], ax=axs[0, 1])
plt.show()

# %% [markdown]
#  According to the boxplot,the WATT has no outliers while the Quantity has normal distribution with few outliers.

# %% [markdown]
# ## **USING HISTOGRAM TO CHECK DISTRIBUTION**

# %%
# Create histograms for WATT and QTY
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(data=df, x="WATT", kde=True, color="skyblue", ax=axs[0])
sns.histplot(data=df, x="QTY", kde=True, color="olive", ax=axs[1])
plt.show()

# %% [markdown]
# This analysis was useful in analyzing the sales volumn of each watt and their growth which will help improve sales for 2024
